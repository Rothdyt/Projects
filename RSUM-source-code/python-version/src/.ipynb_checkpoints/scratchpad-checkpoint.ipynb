# %%
import numpy as np
from utils import plot_utils

# %%
plot_utils(name='BreastCancerDuke', title='N = 44, p = 7129', gap=True)
# Out:
# [Time] [Lambda]:0.01 | RCSUM:97.38588738441467 | CSUM:86.6471107006073 | CGD:102.8754506111145 | APCG:215.3632094860077
# [Epoch] [Lambda]:0.01 | RCSUM:102 | CSUM:90 | CGD:41 | APCG:82
# [Time] [Lambda]:0.001 | RCSUM:337.6603922843933 | CSUM:306.9363875389099 | CGD:96.49933362007141 | APCG:717.9240367412567
# [Epoch] [Lambda]:0.001 | RCSUM:354 | CSUM:321 | CGD:38 | APCG:263

# %%
plot_utils(name='rnaCod', title="N = 271617, p = 8", gap=True)
# Out:
# [Time] [Lambda]:0.01 | RCSUM:4.280070066452026 | CSUM:4.044095754623413 | CGD:2.430814743041992 | APCG:4.083641529083252
# [Epoch] [Lambda]:0.01 | RCSUM:55 | CSUM:52 | CGD:16 | APCG:45
# [Time] [Lambda]:0.001 | RCSUM:17.410139799118042 | CSUM:16.991673707962036 | CGD:5.285343170166016 | APCG:10.729657649993896
# [Epoch] [Lambda]:0.001 | RCSUM:229 | CSUM:225 | CGD:35 | APCG:119

# %%
plot_utils(name='glmnet', title="N=100, p=30", gap=True)
# Out:
# [Time] [Lambda]:0.01 | RCSUM:0.07303023338317871 | CSUM:0.0689692497253418 | CGD:0.040316104888916016 | APCG:0.10504603385925293
# [Epoch] [Lambda]:0.01 | RCSUM:22 | CSUM:22 | CGD:8 | APCG:24
# [Time] [Lambda]:0.001 | RCSUM:0.9793622493743896 | CSUM:0.9025261402130127 | CGD:0.19987249374389648 | APCG:1.1574902534484863
# [Epoch] [Lambda]:0.001 | RCSUM:309 | CSUM:307 | CGD:41 | APCG:270

# %%
plot_utils(name='simulation', title="N=1000, p=100, rho=0.5", gap=True)
# Out:
# [Time] [Lambda]:0.01 | RCSUM:0.24324798583984375 | CSUM:0.4497694969177246 | CGD:1.2176704406738281 | APCG:0.48720455169677734
# [Epoch] [Lambda]:0.01 | RCSUM:14 | CSUM:22 | CGD:27 | APCG:16
# [Time] [Lambda]:0.001 | RCSUM:0.7651112079620361 | CSUM:1.6792271137237549 | CGD:6.620559930801392 | APCG:1.109377145767212
# [Epoch] [Lambda]:0.001 | RCSUM:38 | CSUM:85 | CGD:138 | APCG:37

# %%
plot_utils(name='Leukemia', title="N=38, p=7129", gap=True)
# Out:
# [Time] [Lambda]:0.01 | RCSUM:139.6157205104828 | CSUM:138.0859625339508 | CGD:107.41196274757385 | APCG:222.0724654197693
# [Epoch] [Lambda]:0.01 | RCSUM:153 | CSUM:150 | CGD:45 | APCG:83
# [Time] [Lambda]:0.001 | RCSUM:298.52861523628235 | CSUM:308.7913122177124 | CGD:57.79104542732239 | APCG:555.289947271347
# [Epoch] [Lambda]:0.001 | RCSUM:321 | CSUM:335 | CGD:24 | APCG:206

# %%
plot_utils(name='wisc-b', title="N=638, p=10", gap=True)
# Out:
# [Time] [Lambda]:0.01 | RCSUM:0.06863069534301758 | CSUM:0.07078385353088379 | CGD:0.031668901443481445 | APCG:0.08053922653198242
# [Epoch] [Lambda]:0.01 | RCSUM:44 | CSUM:52 | CGD:12 | APCG:41
# [Time] [Lambda]:0.001 | RCSUM:0.1184844970703125 | CSUM:0.16673922538757324 | CGD:0.022714853286743164 | APCG:0.16349029541015625
# [Epoch] [Lambda]:0.001 | RCSUM:86 | CSUM:123 | CGD:7 | APCG:85

# %%
plot_utils(name='covtype', title="N=581012, p=54", gap=True)
# Out:
# [Time] [Lambda]:0.01 | RCSUM:47.92967462539673 | CSUM:42.352051973342896 | CGD:51.80385661125183 | APCG:47.826101541519165
# [Epoch] [Lambda]:0.01 | RCSUM:19 | CSUM:17 | CGD:11 | APCG:18
# [Time] [Lambda]:0.001 | RCSUM:103.21221613883972 | CSUM:110.35101294517517 | CGD:153.78652381896973 | APCG:82.3608467578888
# [Epoch] [Lambda]:0.001 | RCSUM:39 | CSUM:44 | CGD:31 | APCG:31

# %%
plot_utils(name='susy', title="N=5000000, p=18", gap=True)
# Out:
# [Time] [Lambda]:0.01 | RCSUM:351.2634813785553 | CSUM:244.29417037963867 | CGD:124.43463468551636 | APCG:227.64885640144348
# [Epoch] [Lambda]:0.01 | RCSUM:46 | CSUM:32 | CGD:9 | APCG:30
# [Time] [Lambda]:0.001 | RCSUM:1424.8961856365204 | CSUM:972.9482634067535 | CGD:590.5473668575287 | APCG:765.8001585006714
# [Epoch] [Lambda]:0.001 | RCSUM:186 | CSUM:135 | CGD:44 | APCG:101

# %%
import numpy.linalg as la
import pickle
pickled = pickle.load(open("../db/n1000-p100-rho0.5.pkl", "rb"))
X = pickled['X']
la.cond(X)
# Out:
# 14.286346890310654

# %%
from sklearn.datasets import load_svmlight_file
data = load_svmlight_file("../db/covtype.libsvm.binary.bz2")
X, y = data[0].toarray(), data[1].reshape(-1, 1)
y[y == 2] = 0
X = (X - np.mean(X, axis=0)) / np.std(X, axis=0)
la.cond(X)
# Out:
# 5202541737428943.0
