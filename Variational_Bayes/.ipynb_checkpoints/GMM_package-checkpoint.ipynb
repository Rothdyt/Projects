# %%
import itertools
import pandas as pd
import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn import mixture

# %%
import cv2
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join
img_folder = "./image_use/"
imgs = [f for f in listdir(img_folder) if isfile(join(img_folder, f))]

# %%
imgs[0]
imgs.pop(0)
# Out:
# '.DS_Store'

# %%
save = []
for img in imgs:
    img_data = cv2.imread('image_use/{}'.format(img))
    color = ('b','g','r')
    im =np.array([])
    for i,col in enumerate(color):
        histr = cv2.calcHist([img_data],[i],None,[196],[30,226])
        histr = histr.flatten()
        im = np.concatenate((im, histr))
    save.append(im)
save = np.asarray(save)

# %%
save = save[0:5000,]

# %%
save.shape
# Out:
# (5000, 588)

# %%
result = mixture.BayesianGaussianMixture(n_components=30, weight_concentration_prior_type="dirichlet_distribution",
                                        covariance_type='full', n_init = 5, tol = 1e-4).fit(save)

# %%
cluster = result.predict(save)

# %%
label_ = np.array(imgs)[0:5000,]

# %%
import PIL
from PIL import Image

# %%
size = 400
import matplotlib.pyplot as plt
img_path = label_[cluster == 22]
for j in range(1):
    random_idx = np.random.choice(range(1, img_path.shape[0]+1), size = 9, replace=False)
    for i, img_idx in enumerate(random_idx):
        plt.subplot(3, 3, i+1)
        plt.subplots_adjust(wspace =0, hspace =0,left  = 0.17,right = 0.8)
        img_data = Image.open('image_use/{}'.format(img_path[img_idx]))
        img_data = img_data.resize((size+100, size), PIL.Image.ANTIALIAS)
        plt.imshow(img_data)
        plt.axis('off')
    plt.savefig('1.jpg')
    plt.show()

# %%
import cv2
import os
import numpy as np
img_folder = "./data/iaprtc12/processed/"
sub_folder = [(f,os.path.join(img_folder, f)) for f in os.listdir(img_folder) if os.path.isdir(os.path.join(img_folder, f)) and f != '.ipynb_checkpoints']
db = {}
for i in range(len(sub_folder)):
    key, item = sub_folder[i]
    db[key] = [os.path.join(item, f) for f in os.listdir(item) if os.path.isfile(os.path.join(item, f)) and f != ".DS_Store"]

# %%
save = []
img_paths = []
for key in db.keys():
    print("process class {}".format(key))
    img_class = db[key]
    for img in img_class:
        img_paths.append(img)
        img_data = cv2.imread(img)
        color = ('b','g','r')
        im =np.array([])
        for i,col in enumerate(color):
            histr = cv2.calcHist([img_data],[i],None,[196],[30,226])
            histr = histr.flatten()
            im = np.concatenate((im, histr))
        save.append(im)
save = np.asarray(save)
# Out:
# process class 00
# process class 01
# process class 02
# process class 03
# process class 04
# process class 05
# process class 06
# process class 07
# process class 08
# process class 09
# process class 10
# process class 11
# process class 12
# process class 13
# process class 14
# process class 15
# process class 16
# process class 17
# process class 18
# process class 19
# process class 20
# process class 21
# process class 22
# process class 23
# process class 24
# process class 25
# process class 26
# process class 27
# process class 30
# process class 31
# process class 32
# process class 33
# process class 34
# process class 35
# process class 36
# process class 37
# process class 38
# process class 39
# process class 40

# %%
from sklearn import mixture
result = mixture.BayesianGaussianMixture(n_components=30, weight_concentration_prior_type="dirichlet_distribution",
                                        covariance_type='full', n_init = 5, tol = 1e-4).fit(save)

# %%
cluster = result.predict(save)

# %%
label_ = np.array(img_paths)
import matplotlib.pyplot as plt
for img_class in range(30):
    print("process class {}".format(img_class))
    img_path = label_[cluster == img_class]
    if img_path.shape[0] > 1:
        random_idx = np.random.choice(range(1, img_path.shape[0]), size = 9, replace=False)
        for i, img_idx in enumerate(random_idx):
            plt.subplot(3, 3, i+1)
            plt.subplots_adjust(wspace =0, hspace =0,left  = 0.3,right = 0.8)
            img_data = Image.open(img_path[img_idx])
            plt.imshow(img_data)
            plt.axis('off')
        plt.savefig('./outputs/calssification/{}.jpg'.format(img_class), dpi=300)
# Out:
# process class 0
# process class 1
# process class 2
# process class 3
# process class 4
# process class 5
# process class 6
# process class 7
# process class 8
# process class 9
# process class 10
# process class 11
# process class 12
# process class 13
# process class 14
# process class 15
# process class 16
# process class 17
# process class 18
# process class 19
# process class 20
# process class 21
# process class 22
# process class 23
# process class 24
# process class 25
# process class 26
# process class 27
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-494ca75fde9e> in <module>()
#       4     print("process class {}".format(img_class))
#       5     img_path = label_[cluster == img_class]
# ----> 6     random_idx = np.random.choice(range(1, img_path.shape[0]), size = 9, replace=False)
#       7     for i, img_idx in enumerate(random_idx):
#       8         plt.subplot(3, 3, i+1)
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ValueError: a must be non-empty

# %%
out_dir = './outputs/calssification/'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

# %%
np.random.choice(range(1, img_path.shape[0]), size = 9, replace=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-500382e8cf43> in <module>()
# ----> 1 np.random.choice(range(1, img_path.shape[0]), size = 9, replace=False)
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ValueError: a must be non-empty

# %%
img_path.shape[0]
# Out:
# 1
